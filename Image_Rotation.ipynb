# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("tes-img/num3.png",0)
plt.imshow(img)

# %%
left=img[::-1].T
plt.imshow(left)

# %%
left=img[::-1].T
bottom=left[::-1].T
plt.imshow(bottom)

# %%
right=bottom[::-1].T
plt.imshow(right)

# %%
top=right[::-1].T
plt.imshow(top)
